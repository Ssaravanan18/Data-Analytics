# %% [markdown]
# <a href="https://colab.research.google.com/github/Ssaravanan18/Data-Analytics/blob/main/bookdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's load up the hotel booking data

# %%
df=pd.read_csv("booking_dataset.txt",delimiter='\t')
df.head(10)
# Out:
#          Date   Company          Person Name  Room number
# 0  1-Jan-2022    Avamba    Anatole Ridehalgh       4008.0
# 1  1-Jan-2022      Fatz      Aldrich McKevin       2002.0
# 2  1-Jan-2022     Leexo      Stanley Hadrill       4012.0
# 3      Hotels       NaN                  NaN          NaN
# 4  1-Jan-2022    Rhyzio         Lyndell Tice       1006.0
# 5  1-Jan-2022     Eadel  Broderic Handscombe       3015.0
# 6  1-Jan-2022      Oozz         Deina Harwin       2005.0
# 7  1-Jan-2022  Innotype    Benyamin Crocetti       2001.0
# 8  1-Jan-2022       NaN           Thea Melan       5006.0
# 9  1-Jan-2022       NaN        Alexei Kneale       3002.0

# %% [markdown]
# using the delimiter='\t' that remove \t and data much clear

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Quinu           3
# Fivechat        3
# Twitterlist     2
# Jayo            2
#                ..
# Twitterwire     1
# Skiba           1
# Tagpad          1
# Innojam         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# now remove all NaN columns from the data

# %%
df.dropna(inplace=True)

# %% [markdown]
# create a new column called 2xroom

# %%
df['2xroom']=df['Room number']*2
df.head(10)
# Out:
#           Date    Company          Person Name  Room number  2xroom
# 0   1-Jan-2022     Avamba    Anatole Ridehalgh       4008.0  8016.0
# 1   1-Jan-2022       Fatz      Aldrich McKevin       2002.0  4004.0
# 2   1-Jan-2022      Leexo      Stanley Hadrill       4012.0  8024.0
# 4   1-Jan-2022     Rhyzio         Lyndell Tice       1006.0  2012.0
# 5   1-Jan-2022      Eadel  Broderic Handscombe       3015.0  6030.0
# 6   1-Jan-2022       Oozz         Deina Harwin       2005.0  4010.0
# 7   1-Jan-2022   Innotype    Benyamin Crocetti       2001.0  4002.0
# 10  1-Jan-2022       Jayo      Tate Manntschke       3014.0  6028.0
# 13  1-Jan-2022  Riffpedia       Elianore Vigar       3002.0  6004.0
# 14  1-Jan-2022       Tazz        Alonso Mundee       4006.0  8012.0

# %%
df.columns.isna().any()
# Out:
# np.False_

# %% [markdown]
# create a new columns

# %%
df['Status'] = 'Booked'
display(df.head())
# Out:
#          Date Company          Person Name  Room number  2xroom  Status
# 0  1-Jan-2022  Avamba    Anatole Ridehalgh       4008.0  8016.0  Booked
# 1  1-Jan-2022    Fatz      Aldrich McKevin       2002.0  4004.0  Booked
# 2  1-Jan-2022   Leexo      Stanley Hadrill       4012.0  8024.0  Booked
# 4  1-Jan-2022  Rhyzio         Lyndell Tice       1006.0  2012.0  Booked
# 5  1-Jan-2022   Eadel  Broderic Handscombe       3015.0  6030.0  Booked

# %% [markdown]
# You can also create a new column based on calculations or conditions involving existing columns, just like you did with `df['2xroom'] = df['Room number'] * 2`.

# %%
df.value_counts('Status')
# Out:
# Status
# Booked    134
# Name: count, dtype: int64

# %% [markdown]
# creat a plot chart

# %%
plt=df.value_counts('Company')
plt.plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
plt=df.value_counts('Company')
plt.plot()
# Out:
# <Axes: xlabel='Company'>
